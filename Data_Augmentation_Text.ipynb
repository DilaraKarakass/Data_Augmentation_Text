# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
dataFrame = pd.read_csv("emotions.csv") 
import pandas as pd

# %%
dataFrame.head()
# Out:
#   Unnamed: 0.1  Unnamed: 0                                               Text  \
# 0            0         0.0   Enjoying a beautiful day at the park!        ...
# 1            1         1.0   Traffic was terrible this morning.           ...
# 2            2         2.0   Just finished an amazing workout! 💪          ...
# 3            3         3.0   Excited about the upcoming weekend getaway!  ...
# 4            4         4.0   Trying out a new recipe for dinner tonight.  ...
#
#      Sentiment            Timestamp            User     Platform  \
# 0   Positive    2023-01-15 12:30:00   User123          Twitter
# 1   Negative    2023-01-15 08:45:00   CommuterX        Twitter
# 2   Positive    2023-01-15 15:45:00   FitnessFan      Instagram
# 3   Positive    2023-01-15 18:20:00   AdventureX       Facebook
# 4   Neutral     2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...
